# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("salaries.csv")

# %%
data
# Out:
#        work_year experience_level employment_type                  job_title  \
# 0           2024               SE              FT                AI Engineer
# 1           2024               SE              FT  Machine Learning Engineer
# 2           2024               SE              FT  Machine Learning Engineer
# 3           2024               SE              FT  Machine Learning Engineer
# 4           2024               SE              FT  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 13967       2020               SE              FT             Data Scientist
# 13968       2021               MI              FT   Principal Data Scientist
# 13969       2020               EN              FT             Data Scientist
# 13970       2020               EN              CT      Business Data Analyst
# 13971       2021               SE              FT       Data Science Manager
#
# ...

# %%
data.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2024               SE              FT                AI Engineer
# 1       2024               SE              FT  Machine Learning Engineer
# 2       2024               SE              FT  Machine Learning Engineer
# 3       2024               SE              FT  Machine Learning Engineer
# 4       2024               SE              FT  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   90000             USD          90000                 AE             0
# 1  180500             USD         180500                 US             0
# 2   96200             USD          96200                 US             0
# 3  235000             USD         235000                 AU             0
# 4  175000             USD         175000                 AU             0
#
#   company_location company_size
# 0               AE            L
# ...

# %%
data.tail()
# Out:
#        work_year experience_level employment_type                 job_title  \
# 13967       2020               SE              FT            Data Scientist
# 13968       2021               MI              FT  Principal Data Scientist
# 13969       2020               EN              FT            Data Scientist
# 13970       2020               EN              CT     Business Data Analyst
# 13971       2021               SE              FT      Data Science Manager
#
#         salary salary_currency  salary_in_usd employee_residence  \
# 13967   412000             USD         412000                 US
# 13968   151000             USD         151000                 US
# 13969   105000             USD         105000                 US
# 13970   100000             USD         100000                 US
# 13971  7000000             INR          94665                 IN
#
#        remote_ratio company_location company_size
# 13967           100               US            L
# ...

# %%
data.shape
# Out:
# (13972, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13972 entries, 0 to 13971
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           13972 non-null  int64
#  1   experience_level    13972 non-null  object
#  2   employment_type     13972 non-null  object
#  3   job_title           13972 non-null  object
#  4   salary              13972 non-null  int64
#  5   salary_currency     13972 non-null  object
#  6   salary_in_usd       13972 non-null  int64
#  7   employee_residence  13972 non-null  object
#  8   remote_ratio        13972 non-null  int64
#  9   company_location    13972 non-null  object
#  10  company_size        13972 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 1.2+ MB

# %%
data.describe()
# Out:
#           work_year        salary  salary_in_usd  remote_ratio
# count  13972.000000  1.397200e+04   13972.000000  13972.000000
# mean    2023.085600  1.660011e+05  150028.812124     33.334526
# std        0.687612  3.661545e+05   68634.306349     46.682931
# min     2020.000000  1.400000e+04   15000.000000      0.000000
# 25%     2023.000000  1.040000e+05  103000.000000      0.000000
# 50%     2023.000000  1.422000e+05  141600.000000      0.000000
# 75%     2024.000000  1.880000e+05  185900.000000    100.000000
# max     2024.000000  3.040000e+07  800000.000000    100.000000

# %%
total_rows, total_columns = data.shape

print("Total number of rows:", total_rows)
print("Total number of columns:", total_columns)
# Out:
# Total number of rows: 13972
# Total number of columns: 11

# %%
data.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
#replacing the shortform in the column to it's long form 

data['experience_level'].replace({'En':'Entry-Level','MI':"Mid-Level",'EX':'Executive-Level','SE':'Senior'},inplace = True)
data['employment_type'].replace({'PT':'Part-Time','FT':'Full-Time','CT':'Contract','FL':'Freelance'},inplace=True)

# %%
data
# Out:
#        work_year experience_level employment_type                  job_title  \
# 0           2024           Senior       Full-Time                AI Engineer
# 1           2024           Senior       Full-Time  Machine Learning Engineer
# 2           2024           Senior       Full-Time  Machine Learning Engineer
# 3           2024           Senior       Full-Time  Machine Learning Engineer
# 4           2024           Senior       Full-Time  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 13967       2020           Senior       Full-Time             Data Scientist
# 13968       2021        Mid-Level       Full-Time   Principal Data Scientist
# 13969       2020      Entry-Level       Full-Time             Data Scientist
# 13970       2020      Entry-Level        Contract      Business Data Analyst
# 13971       2021           Senior       Full-Time       Data Science Manager
#
# ...

# %%
#retrive all the columns of the dataset
data.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
#here we use to retrive the experience level count by the work year

subset = data[['work_year', 'experience_level']] #This creates a new DataFrame called subset containing only these two columns.


# It essentially creates groups based on each unique combination of values in these two columns.

work_experience_counts = subset.groupby(['work_year', 'experience_level']).size()  #This calculates the size of each group, i.e., the number of occurrences of each unique combination of values.

print(work_experience_counts)
# Out:
# work_year  experience_level
# 2020       Entry-Level           21
#            Executive Level        4
#            Mid-Level             31
#            Senior                19
# 2021       Entry-Level           46
#            Executive Level       10
#            Mid-Level             87
#            Senior                75
# 2022       Entry-Level          116
#            Executive Level       41
#            Mid-Level            358
#            Senior              1137
# 2023       Entry-Level          463
#            Executive Level      242
#            Mid-Level           1716
#            Senior              6097
# 2024       Entry-Level          381
#            Executive Level      106
#            Mid-Level           1102
#            Senior              1920
# dtype: int64

# %%
#retriving the employment type and there count by the work year

subset = data[['work_year', 'employment_type']]  #This creates a new DataFrame called subset containing only these two columns.

#this part group the dataframe subset by unique combination of valuesin these 2 column.
work_employment_counts = subset.groupby(['work_year', 'employment_type']).size()  #this is use calculate the size of each group.


print(work_employment_counts)
# Out:
# work_year  employment_type
# 2020       Contract              3
#            Freelance             1
#            Full-Time            69
#            Part-Time             2
# 2021       Contract              3
#            Freelance             3
#            Full-Time           208
#            Part-Time             4
# 2022       Contract              4
#            Freelance             4
#            Full-Time          1638
#            Part-Time             6
# 2023       Contract              9
#            Freelance             4
#            Full-Time          8502
#            Part-Time             3
# 2024       Contract              7
#            Full-Time          3495
#            Part-Time             7
# dtype: int64

# %%
#retriving all the unique job title from the dataset


print(data['job_title'].unique())
# Out:
# ['AI Engineer' 'Machine Learning Engineer'
#  'Business Intelligence Developer' 'Data Engineer' 'Data Scientist'
#  'Cloud Database Engineer' 'Research Engineer' 'Data Analyst'
#  'Machine Learning Scientist' 'Applied Scientist' 'Data Science Manager'
#  'Research Scientist' 'Prompt Engineer' 'Data Science'
#  'Data Science Consultant' 'Data Management Analyst' 'Research Analyst'
#  'Data Operations Analyst' 'Data Management Consultant'
#  'Business Intelligence Analyst' 'Analytics Engineer'
#  'Data Quality Analyst' 'Data Architect' 'Data Manager' 'ML Engineer'
#  'Robotics Software Engineer' 'Machine Learning Researcher' 'AI Architect'
#  'Data DevOps Engineer' 'Business Intelligence' 'AI Software Engineer'
#  'Data Integration Engineer' 'Data Operations Specialist' 'BI Analyst'
#  'Data Product Manager' 'Business Intelligence Engineer' 'Data Specialist'
#  'AI Research Scientist' 'Data Science Director' 'Data Strategist'
# ...

# %%
# Calculate mean salary
mean_salary = data['salary'].mean()
print("Mean salary:", mean_salary)
# Out:
# Mean salary: 166001.13369596336

# %%
#calculating the max salary for the data science job


print("maxximum salary for data science is ",data[data['job_title'] == 'Data Science']['salary'].max())
# Out:
# maxximum salary for data science is  381500

# %%
 #calculating maximum salary for each job title
    
maxximum_salary= data.groupby('job_title')['salary'].max()

# %%
maxximum_salary
# Out:
# job_title
# AI Architect                        800000
# AI Developer                        275000
# AI Engineer                         400000
# AI Product Manager                  212000
# AI Programmer                      4950806
#                                     ...
# Sales Data Analyst                   60000
# Software Data Engineer              210000
# Staff Data Analyst                  179998
# Staff Data Scientist                164000
# Staff Machine Learning Engineer     185000
# Name: salary, Length: 146, dtype: int64

# %%
#calculating minimum salary for each job title
    
minimum_salary= data.groupby('job_title')['salary'].min()

# %%
minimum_salary
# Out:
# job_title
# AI Architect                        99750
# AI Developer                        30000
# AI Engineer                         20000
# AI Product Manager                  93300
# AI Programmer                       30000
#                                     ...
# Sales Data Analyst                  60000
# Software Data Engineer              50000
# Staff Data Analyst                  15000
# Staff Data Scientist               105000
# Staff Machine Learning Engineer    185000
# Name: salary, Length: 146, dtype: int64

# %%
#calculating average salary for each job title

avg_salary= data.groupby('job_title')['salary'].mean()

# %%
avg_salary
# Out:
# job_title
# AI Architect                       252818.750000
# AI Developer                       134684.210526
# AI Engineer                        161188.820225
# AI Product Manager                 141766.666667
# AI Programmer                      764400.857143
#                                        ...
# Sales Data Analyst                  60000.000000
# Software Data Engineer             120000.000000
# Staff Data Analyst                  84999.333333
# Staff Data Scientist               134500.000000
# Staff Machine Learning Engineer    185000.000000
# Name: salary, Length: 146, dtype: float64

# %%
# Relationship between experience level and salary

print("\nMean salary by years of experience:")
print(data.groupby('experience_level')['salary'].mean())
# Out:
# Mean salary by years of experience:
# experience_level
# Entry-Level        133907.911392
# Executive Level    209065.478908
# Mid-Level          162680.715240
# Senior             168871.188473
# Name: salary, dtype: float64

# %%
#calculating the avg salary by the company size

print(data.groupby('company_size')['salary'].mean())
# Out:
# company_size
# L    313556.098650
# M    153404.920115
# S    275701.050562
# Name: salary, dtype: float64

# %%
#calculating the top 10 job titles in the data science

print("the top 10 job title",data['job_title'].value_counts().head(10) #value_counts() method in pandas is used to count the occurrences of unique values in a Series.
)
# Out:
# the top 10 job title Data Engineer                     3017
# Data Scientist                    2874
# Data Analyst                      2079
# Machine Learning Engineer         1466
# Research Scientist                 441
# Analytics Engineer                 387
# Applied Scientist                  367
# Data Architect                     337
# Research Engineer                  260
# Business Intelligence Engineer     216
# Name: job_title, dtype: int64

# %%
# Grouping data by job title and calculating maximum salary for each job title

maxsalary_by_job_title = data.groupby('job_title')['salary'].max() # is a Series object that contains the max salary for each unique job title in the dataset.

# Sorting the maximum salaries in descending order and selecting the top 5

print('top_jobtitles_with_max_salary',maxsalary_by_job_title.sort_values(ascending=False).head(10)) #sorts the maximum salaries in descending order, so the highest maximum salary comes first.
# Out:
# top_jobtitles_with_max_salary job_title
# Data Scientist                    30400000
# BI Data Analyst                   11000000
# ML Engineer                        8500000
# Lead Machine Learning Engineer     7500000
# Data Science Manager               7000000
# Head of Machine Learning           6000000
# Research Engineer                  5500000
# Head of Data Science               5000000
# AI Programmer                      4950806
# Machine Learning Engineer          4900000
# Name: salary, dtype: int64

# %%
# Grouping data by job title and calculating minimum salary for each job title

minsalary_by_job_title = data.groupby('job_title')['salary'].min() #is a Series object that contains the minimum salary for each unique job title in the dataset.

# Sorting the maximum salaries in descending order and selecting the top 5

print('top_jobtitles_with_max_salary',minsalary_by_job_title.sort_values(ascending=True).head(10)) #sorts the maximum salaries in descending order, so the highest maximum salary comes first.
# Out:
# top_jobtitles_with_max_salary job_title
# ML Engineer                        14000
# Data Analyst                       15000
# Data Science                       15000
# Business Intelligence Developer    15000
# Staff Data Analyst                 15000
# Machine Learning Developer         15000
# Research Engineer                  15662
# Data Scientist                     16000
# Business Data Analyst              17000
# Data Engineer                      17598
# Name: salary, dtype: int64

# %%
data.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# # company size analysis with pie chart

# %%
company_size_counts = data['company_size'].value_counts() #count the occurence of unique values in the series.
plt.figure(figsize=(8, 8))      #This line initializes a new figure for plotting with matplotlib and sets its size to be 8x8 inches.
plt.pie(company_size_counts, labels=company_size_counts.index,autopct='%1.1f%%')  #Display the percentage value with one digit after the decimal point.
plt.title('Company Size Distribution')
plt.show()

# %% [markdown]
# # job title analysis/top 5 job titles

# %%
#plt.figure(figsize=(10, 6))

#creat veriable job_title_counts which stores the counts of unique values in the 'job_title' column of the DataFrame
# data.value_counts() is a pandas function that counts the occurrences of unique values in a Series.
job_title_counts = data['job_title'].value_counts()

top_5_job_titles = job_title_counts.head(5)  #This line selects the top 5 most frequent job titles from the job_title_counts variable. 

color=['g','r','b','y']
sns.barplot(x=top_5_job_titles.index, y=top_5_job_titles.values,palette=color)
plt.title('Top 5 Job Titles')
plt.xlabel('Job Title')
plt.ylabel('Frequency')
plt.xticks(rotation=45,color='r',fontsize=10)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4796\3102069913.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_5_job_titles.index, y=top_5_job_titles.values,palette=color)
# C:\Users\HP\AppData\Local\Temp\ipykernel_4796\3102069913.py:10: UserWarning:
# The palette list has fewer values (4) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x=top_5_job_titles.index, y=top_5_job_titles.values,palette=color)

# %% [markdown]
# # Top 5 Highest Salaries by Job Title

# %%
plt.figure(figsize=(10, 6))


#This line sorts the DataFrame data by the 'salary' column in descending order 
data_sorted = data.sort_values(by='salary', ascending=False)

colo =['g','r','b','y']

#This line selects the top 5 rows with the highest salaries from the data_sorted DataFrame.
top_5_salaries = data_sorted.head(5)

sns.barplot(x='job_title', y='salary', data=top_5_salaries,palette=colo)
plt.title('Top 5 Highest Salaries by Job Title')
plt.xlabel('Job Title')
plt.ylabel('Salary')
#plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6328\1836441942.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='job_title', y='salary', data=top_5_salaries,palette=colo)

# %%
#salary distribution by experience level of the employee.

#plt.figure(figsize=(12, 8))
sns.barplot(x='experience_level', y='salary_in_usd',data=data,palette='Accent',saturation=100,ci=None) 
plt.title('Salary Distribution by Experience Level')
plt.xlabel('Experience Level')
plt.ylabel('Salary')
plt.xticks(rotation=45,color='b')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17624\463675465.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='experience_level', y='salary_in_usd',data=data,palette='Accent',saturation=100,ci=None)
# C:\Users\HP\AppData\Local\Temp\ipykernel_17624\463675465.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='experience_level', y='salary_in_usd',data=data,palette='Accent',saturation=100,ci=None)

# %%
#salary in USD over a time by work year

plt.figure(figsize=(12, 6))
sns.lineplot(x='work_year', y='salary_in_usd', data=data, ci = None,marker='o')
plt.title('Trend of Average Salary Over Time')
plt.xlabel('Year')
plt.ylabel('Average Salary in USD')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17624\2893974833.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='work_year', y='salary_in_usd', data=data, ci = None,marker='o')

# %%
#here we analyse the salary distribution by their experience level and also by employment type

#plt.figure(figsize=(12, 8))

c_palette = ['g','y','b','r']
sns.barplot(x='experience_level', y='salary_in_usd',data=data,palette=c_palette,ci=100,saturation=70,hue='employment_type',errcolor='g',errwidth=2)

# hue is use to differentiate the column using another column

plt.title('Salary Distribution by Experience Level')
plt.xlabel('Experience Level')
plt.ylabel('Salary')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17624\3419552567.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 100)` for the same effect.
#
#   sns.barplot(x='experience_level', y='salary_in_usd',data=data,palette=c_palette,ci=100,saturation=70,hue='employment_type',errcolor='g',errwidth=2)
# C:\Users\HP\AppData\Local\Temp\ipykernel_17624\3419552567.py:6: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'g'}` instead.
#
#   sns.barplot(x='experience_level', y='salary_in_usd',data=data,palette=c_palette,ci=100,saturation=70,hue='employment_type',errcolor='g',errwidth=2)
# C:\Users\HP\AppData\Local\Temp\ipykernel_17624\3419552567.py:6: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 2}` instead.
#
# ...

# %%
#salary distribution by employment type.

sns.violinplot(x='employment_type', y='salary_in_usd', data=data, palette='viridis')
plt.title('Salary Distribution by employment type')
plt.xlabel('employment_type')
plt.ylabel('Salary')
plt.xticks(rotation=45,color='r',fontsize=15)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14100\1401684208.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='employment_type', y='salary_in_usd', data=data, palette='viridis')

# %%
#salary distribution by company size.

plt.figure(figsize=(12, 8))
sns.barplot(x='company_size', y='salary_in_usd', data=data, palette='viridis')
plt.title('Salary Distribution by Company Size')
plt.xlabel('Company Size')
plt.ylabel('Salary')
plt.xticks(rotation=20,fontsize=25,color='g')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4796\4008530613.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='company_size', y='salary_in_usd', data=data, palette='viridis')

# %%
# ploting the Histogram for salaries in USD

plt.figure(figsize=(10, 6))
sns.histplot(data['salary_in_usd'], kde=True, bins=30)  # kde is an argument for line on estimated value
plt.title('Distribution of Salaries in USD')
plt.xlabel('Salary in USD')
plt.ylabel('Frequency')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#distribution of remote ration.

plt.figure(figsize=(10, 6))
sns.histplot(data['remote_ratio'], color='green')
plt.title('Distribution of Remote Ratio')
plt.xlabel('Remote Ratio')
plt.ylabel('Frequency')
plt.show()

# %%
#Scatter Plot for Salary and Experience Level

plt.figure(figsize=(10, 6))
sns.scatterplot(x='experience_level', y='salary_in_usd', data=data, hue='experience_level')
plt.title('Salary in USD vs. Experience Level')
plt.xlabel('Experience Level')
plt.ylabel('Salary in USD')
plt.show()

# %%
#salary distribution by job title

plt.figure(figsize=(12, 10))
sns.boxplot(x='job_title', y='salary_in_usd',palette='Accent', data=data.head(20))
plt.title('Salary Distribution by Job Title')
plt.xlabel('Job Title')
plt.ylabel('Salary in USD')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4796\2073088416.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='job_title', y='salary_in_usd',palette='Accent', data=data.head(20))

# %%
#salary distribution over a time by company size.

plt.figure(figsize=(10, 6))
p = sns.lineplot(data=data, x='work_year', y='salary_in_usd', hue='company_size',ci=None, marker='o')

plt.xlabel('Year Work', fontsize=12, fontweight='bold')
plt.ylabel('Salary in USD', fontsize=12, fontweight='bold')

# Add a title
plt.title('Salary Trend Over Time by Company Size', fontsize=14, fontweight='bold')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6328\1067748724.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   p = sns.lineplot(data=data, x='work_year', y='salary_in_usd', hue='company_size',ci=None, marker='o')

# %%
# Group data by 'job_title' and calculate the average salary for each title

job_title_salary= data.groupby('job_title')['salary_in_usd'].mean().sort_values(ascending = False)

plt.figure(figsize = (10,6))
p = sns.barplot(x= job_title_salary.values[:10], y = job_title_salary.index[:10],palette='Accent')

plt.title('Average Salary by Job Title (Top 10)', fontsize=12, fontweight='bold')
plt.xlabel('Average Salary (USD)', fontsize=12, fontweight='bold')
plt.ylabel('Job Title', fontsize=12, fontweight='bold')
               
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17624\3977229612.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   p = sns.barplot(x= job_title_salary.values[:10], y = job_title_salary.index[:10],palette='Accent')

# %%
plt.figure(figsize=(10, 6))
p = sns.lineplot(data=data, x='work_year', y='job_title',ci=None, marker='o')

plt.xlabel('Year Work', fontsize=12, fontweight='bold')
plt.ylabel('job title ', fontsize=12, fontweight='bold')

# Add a title
plt.title('job title Trend Over Time', fontsize=14, fontweight='bold')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2188\1465897734.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   p = sns.lineplot(data=data, x='work_year', y='job_title',ci=None, marker='o')
